# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Files, Folders and OS (Need)</span></div>

# %% [markdown]
# ## 1 Important concepts

# %% [markdown]
# ### 1.1 Path

# %% [markdown]
# ### 1.2 More about relative paths

# %% [markdown]
# .\data-files\data-01.txt means the file data-01.txt in the folder data-files in the current folder.
#
# ..\data-files\data-01.txt means the file data-01.txt in the folder data-files located in the folder above.

# %% [markdown]
# ### 1.3 Path separator

# %% [markdown]
# windows uses \ as path separator

# %% [markdown]
# ### Text files vs Binary files

# %%
# Your code here

# %% [markdown]
# ### Extentions

# %%
# Your code here

# %% [markdown]
# ### 1.4 Opening and closing files

# %%
with open('spectrum-01.txt', 'r') as file:
    file_content = file.read()

print(file_content)

#open() function opens a ‘stream’ into your file. The 'r' specifies that I only want to read from the file. Using with frees you from worrying about closing the file stream after you are done.
# Out:
# Light Intensity, Ch A vs Actual Angular Position, Run #4
# Actual Angular Position (  )	Light Intensity, Ch A ( % max )
# 0.000	-0.2
# 0.000	-0.1
# 0.000	-0.1
# 0.000	-0.1
# 0.000	-0.1
# 0.000	-0.2
# 0.000	-0.1
# 0.000	-0.1
# 0.000	-0.1
# 0.000	-0.2
# 0.000	-0.1
# 0.000	-0.1
# 0.000	-0.2
# 0.000	-0.3
# 0.000	-0.2
# 0.000	-0.2
# 0.001	-0.1
# 0.001	-0.1
# 0.001	-0.1
# 0.001	-0.1
# 0.001	-0.1
# 0.001	-0.1
# 0.004	-0.1
# 0.010	-0.2
# 0.018	-0.2
# 0.024	-0.3
# 0.029	-0.3
# 0.033	-0.3
# 0.036	-0.2
# 0.039	-0.1
# 0.043	-0.1
# 0.047	-0.1
# 0.053	-0.1
# 0.060	-0.1
# 0.066	-0.1
# 0.069	-0.1
# 0.073	-0.1
# 0.076	-0.1
# 0.079	-0.1
# 0.081	-0.1
# 0.082	-0.1
# 0.083	-0.2
# 0.083	-0.2
# 0.086	-0.2
# 0.090	-0.2
# 0.095	-0.2
# 0.100	-0.3
# 0.103	-0.3
# 0.104	-0.2
# 0.105	-0.3
# 0.107	-0.2
# 0.110	-0.2
# 0.115	-0.1
# 0.122	-0.2
# 0.128	-0.1
# 0.134	-0.2
# 0.139	-0.1
# 0.144	-0.2
# 0.150	-0.2
# 0.157	-0.2
# 0.164	-0.2
# 0.170	-0.3
# 0.175	-0.3
# 0.180	-0.2
# 0.185	-0.2
# 0.191	-0.1
# 0.195	-0.1
# ...

# %%
text = 'Far out in the uncharted backwaters of the unfashionable end of the western spiral arm of the Galaxy lies a small unregarded yellow sun.\nOrbiting this at a distance of roughly ninety-two million miles is an utterly insignificant little blue green planet whose ape-descended life forms are so amazingly primitive that they still think digital watches are a pretty neat idea.'
with open('my-text-once.txt', 'w') as file:  #'w' indicates that I am opening the file stream for writing.
    file.write(text)

# %%
with open('my-text-lines.txt', 'w') as file:
    for line in text.splitlines():  #how to write a line at a time. This is useful when writing data that is being generated on the fly. 
        file.writelines(line)

# %% [markdown]
# ## 2 Playing with the OS

# %% [markdown]
# ### 2.1 Some packages

# %%
import os
import glob
import shutil

# %% [markdown]
# ### 2.2 OS safe paths

# %%
path = os.path.join('.', 'all-data', 'sg-data', 'data-01.txt')
print(path)
# Out:
# .\all-data\sg-data\data-01.txt

# %% [markdown]
# ### 2.3 Creating folders

# %%
os.mkdir('people')

for person in ['Jonh', 'Paul', 'Ringo']:
    path = os.path.join('people', person)
    print(f'Creating {path}')
    os.mkdir(path)
    
#actl dont need print() statement, but including it allows some feedback on what is (or what isnt) happening
# Out:
# Creating people\Jonh
# Creating people\Paul
# Creating people\Ringo

# %% [markdown]
# ### 2.4 Checking for existence

# %%
#using try-except
for person in ['Jonh', 'Paul', 'Ringo']:
    path = os.path.join('people', person)
    try:
        os.mkdir(path)
        print(f'Creating {path}')  #not essential
    except FileExistsError:
        print(f'{path} already exists; skipping creation.')
# Out:
# people\Jonh already exists; skipping creation.
# people\Paul already exists; skipping creation.
# people\Ringo already exists; skipping creation.

# %%
#using os.path.exists()
for person in ['Jonh', 'Paul', 'Ringo']:
    path = os.path.join('people', person)
    if os.path.exists(path):
        print(f'{path} already exists; skipping creation.')
    else:
        os.mkdir(path)
        print(f'Creating {path}')
# Out:
# people\Jonh already exists; skipping creation.
# people\Paul already exists; skipping creation.
# people\Ringo already exists; skipping creation.

# %% [markdown]
# ### 2.5 Copying files

# %%
for person in ['Jonh', 'Paul', 'Ringo']:
    path_to_destination = os.path.join('people', person)
    shutil.copy('sp2273_logo.png', path_to_destination)
    print(f'Copied file to {path_to_destination}')
# Out:
# Copied file to people\Jonh
# Copied file to people\Paul
# Copied file to people\Ringo

# %%
for person in ['Jonh', 'Paul', 'Ringo']:
    # Create folder 'imgs'
    path_to_imgs = os.path.join('people', person, 'imgs')
    if not os.path.exists(path_to_imgs):
        os.mkdir(path_to_imgs)

    # Move logo file
    current_path_of_logo = os.path.join('people', person, 'sp2273_logo.png')
    new_path_of_logo = os.path.join('people', person, 'imgs', 'sp2273_logo.png')

    shutil.move(current_path_of_logo, new_path_of_logo)
    print(f'Moved logo to {new_path_of_logo}')
# Out:
# Moved logo to people\Jonh\imgs\sp2273_logo.png
# Moved logo to people\Paul\imgs\sp2273_logo.png
# Moved logo to people\Ringo\imgs\sp2273_logo.png

# %% [markdown]
# ### 2.6 Listing files

# %%
glob.glob('*')   #* is read as anything
# Out:
# ['files,_folders_and_os_(need).ipynb',
#  'my-text-lines.txt',
#  'my-text-once.txt',
#  'people',
#  'sp2273_logo.png',
#  'spectrum-01.txt']

# %%
glob.glob('peo*') # give those files that match the pattern ‘peo’ followed by ‘anything’.
# Out:
# ['people']

# %%
glob.glob('peo*\*')  #give what's inside the folder people
# Out:
# ['people\\Jonh', 'people\\Paul', 'people\\Ringo']

# %%
glob.glob('people/**', recursive=True)  #search recursively (i.e. dig through all sub-file directories) by putting recursive=True
                                        #need two *
# Out:
# ['people\\',
#  'people\\Jonh',
#  'people\\Jonh\\imgs',
#  'people\\Jonh\\imgs\\sp2273_logo.png',
#  'people\\Paul',
#  'people\\Paul\\imgs',
#  'people\\Paul\\imgs\\sp2273_logo.png',
#  'people\\Ringo',
#  'people\\Ringo\\imgs',
#  'people\\Ringo\\imgs\\sp2273_logo.png']

# %%
glob.glob('people/**/*.png', recursive=True)
# Out:
# ['people\\Jonh\\imgs\\sp2273_logo.png',
#  'people\\Paul\\imgs\\sp2273_logo.png',
#  'people\\Ringo\\imgs\\sp2273_logo.png']

# %% [markdown]
# ### 2.7 Moving about

# %%
os.getcwd()   #get Current Working Directory
# Out:
# 'C:\\Users\\ntyl1\\Documents\\GitHub\\learning-portfolio-ntyl03\\files, folders and os'

# %%
os.chdir('people/Ringo') #to (programmatically) move around in your file structure. For this, you just need to CHange DIRectory

# %% [markdown]
# ### 2.8 Extracting Info

# %%
path = 'people/Ringo/imgs/sp2273_logo.png'
filename = path.split(os.path.sep)[-1]  #os.path.sep is the path separator (i.e. \ or /) for the OS. 
extension = filename.split('.')[-1]
print(filename, extension)
# Out:
# people/Ringo/imgs/sp2273_logo.png png

# %%
path = 'people/Ringo/imgs/sp2273_logo.png'
os.path.split(path)      # Split filename from the rest
# Out:
# ('people/Ringo/imgs', 'sp2273_logo.png')

# %%
os.path.splitext(path)   # Split extension
# Out:
# ('people/Ringo/imgs/sp2273_logo', '.png')

# %%
#os.path.dirname(path)    # Show the directory
# Out:
# 'people/Ringo/imgs'

# %% [markdown]
# ### 2.9 Deleting stuff

# %%
os.getcwd()
# os.chdir("..")

os.remove('people/Ringo/imgs/sp2273_logo.png')  #to remove file

# %%
os.rmdir('people/Ringo/imgs')   #for empty directory

# %%
shutil.rmtree('people/Ringo')  #for directory w files

# %% [markdown]
# ## Exercise 7 :  The OS is my oyster

# %%
os.getcwd()
#os.mkdir('python_today')
#os.chdir('python_today')

#make 50 new directories 
    
#for i in range (1,51):                          
    #os.mkdir(f"new_directory_{str(i).zfill(2)}")

# %%
#remove odd numbered directories using a fixed interval of 2

#for i in range(1,51,2):                           
    #os.rmdir(f"new_directory_{str(i).zfill(2)}")

# %%
#check only even numbered directories are left

#os.listdir()
# Out:
# ['new_directory_02',
#  'new_directory_04',
#  'new_directory_06',
#  'new_directory_08',
#  'new_directory_10',
#  'new_directory_12',
#  'new_directory_14',
#  'new_directory_16',
#  'new_directory_18',
#  'new_directory_20',
#  'new_directory_22',
#  'new_directory_24',
#  'new_directory_26',
#  'new_directory_28',
#  'new_directory_30',
#  'new_directory_32',
#  'new_directory_34',
#  'new_directory_36',
#  'new_directory_38',
#  'new_directory_40',
#  'new_directory_42',
#  'new_directory_44',
#  'new_directory_46',
#  'new_directory_48',
#  'new_directory_50']

# %%
#renaming every 5th directory. since only even numbered ones are left, interval is 10

# for i in range(10,51,10):
#     os.rename (f"new_directory_{str(i).zfill(2)}", f"haha_{str(i).zfill(2)}")

# %%
#if there file exists, skip. if no file, will make the file.

# for i in range (10,51,10):
#     if os.path.exists(f"haha_{str(i).zfill(2)}"):
#         print(f"haha_{str(i).zfill(2)} already exists; skipping creation")
#     else:
#         os.mkdir(f"haha_{str(i).zfill(2)}")
#         print (f"haha_{str(i).zfill(2)}")
# Out:
# haha_10 already exists; skipping creation
# haha_20 already exists; skipping creation
# haha_30 already exists; skipping creation
# haha_40 already exists; skipping creation
# haha_50 already exists; skipping creation

# %%
#to check list of files

# os.listdir()
# Out:
# ['haha_10',
#  'haha_20',
#  'haha_30',
#  'haha_40',
#  'haha_50',
#  'new_directory_02',
#  'new_directory_04',
#  'new_directory_06',
#  'new_directory_08',
#  'new_directory_12',
#  'new_directory_14',
#  'new_directory_16',
#  'new_directory_18',
#  'new_directory_22',
#  'new_directory_24',
#  'new_directory_26',
#  'new_directory_28',
#  'new_directory_32',
#  'new_directory_34',
#  'new_directory_36',
#  'new_directory_38',
#  'new_directory_42',
#  'new_directory_44',
#  'new_directory_46',
#  'new_directory_48']

# %%
# copy the photo to all the haha folders. 

# x=os.path.join("..",'sp2273_logo.png')
# for i in range(10,51,10):
#     shutil.copy(x, f"haha_{str(i).zfill(2)}")

# %%
#glob.glob('haha_*/*')

# %%
#os.listdir()
# Out:
# ['haha_10',
#  'haha_20',
#  'haha_30',
#  'haha_40',
#  'haha_50',
#  'new_directory_02',
#  'new_directory_04',
#  'new_directory_06',
#  'new_directory_08',
#  'new_directory_12',
#  'new_directory_14',
#  'new_directory_16',
#  'new_directory_18',
#  'new_directory_22',
#  'new_directory_24',
#  'new_directory_26',
#  'new_directory_28',
#  'new_directory_32',
#  'new_directory_34',
#  'new_directory_36',
#  'new_directory_38',
#  'new_directory_42',
#  'new_directory_44',
#  'new_directory_46',
#  'new_directory_48']

# %% [markdown]
# ## Exercise 8 :  Tidying a collaboration

# %%
# Out:
# 'C:\\Users\\ntyl1\\Documents\\GitHub\\learning-portfolio-ntyl03\\files, folders and os\\os-collaboration-exercise-data'

# %%
convert = {
'jan': '01', 'feb': '02', 'mar': '03',
'apr': '04', 'may': '05', 'jun': '06',
'jul': '07', 'aug': '08', 'sep': '09',
'oct': '10', 'nov': '11', 'dec': '12'
}

sample = ['oct-08_singapore.txt', 'jul-10_cairo.txt', 'may-15_dhaka.txt',
 'may-13_cairo.txt', 'oct-21_cairo.txt', 'jan-10_singapore.txt',
 'jun-20_tokyo.txt', 'aug-06_jakarta.txt', 'dec-21_karachi.txt',
 'jan-01_tokyo.txt']

#need to split up old file name to replace underscore with dash at the back part, and then add it back to the front part 
def rename_my_file(old_file_name):
    end = old_file_name.split('-')[1]
    underscore = end.replace('_','-') 
    new_file_name =(f"{convert[old_file_name.split('-')[0]]}-{underscore}")
    return new_file_name

# %%
#renaming all elements in sample using function

for i in range(len(sample)):
    renamed_s = rename_my_file(sample[i])
    print(renamed_s)
    #forgot to print progress in the form old-file-name ----> new-file-name and a bit scared to re-run code since action alr done but aware that it is through use of f string.
# Out:
# 10-08-singapore.txt
# 07-10-cairo.txt
# 05-15-dhaka.txt
# 05-13-cairo.txt
# 10-21-cairo.txt
# 01-10-singapore.txt
# 06-20-tokyo.txt
# 08-06-jakarta.txt
# 12-21-karachi.txt
# 01-01-tokyo.txt

# %%
#renaming all txt files. use of glob glob to filter out the relevant files. 

# txt_files = glob.glob('*-*_*.txt')
#print(txt_files)
# for i in range(len(txt_files)):
#     os.rename(txt_files[i], rename_my_file(txt_files[i]))

# %%
countries = ['Cairo', 'Dhaka', 'Jakarta', 'Karachi', 'Manila',
 'Melbourne', 'Osaka', 'Shanghai', 'Singapore', 'Tokyo']

#created folders named after each element in lsit

# for country in countries:
#     os.mkdir(country)

# %%
#use glob glob to filter out cairo files

cairo_files = glob.glob('*cairo.*')  #can also just be '*cairo.'
# print(cairo_files)

# %%
# copy all the filtered files to folder

# for cairo in cairo_files:
#     shutil.copy(cairo, 'Cairo')

# %%
#modified above two cells of code to apply for all other files and their corresponding cities

for i in countries:
    for f in glob.glob(f'*{i}.*'):
        print(f)
        shutil.move(f, f'{i}')
# Out:
# 01-02-cairo.txt
# 01-03-cairo.txt
# 01-04-cairo.txt
# 01-05-cairo.txt
# 01-07-cairo.txt
# 01-08-cairo.txt
# 01-09-cairo.txt
# 01-11-cairo.txt
# 01-12-cairo.txt
# 01-13-cairo.txt
# 01-15-cairo.txt
# 01-16-cairo.txt
# 01-19-cairo.txt
# 01-20-cairo.txt
# 01-21-cairo.txt
# 01-23-cairo.txt
# 01-27-cairo.txt
# 01-30-cairo.txt
# 02-10-cairo.txt
# 02-17-cairo.txt
# 02-20-cairo.txt
# 02-22-cairo.txt
# 02-25-cairo.txt
# 02-26-cairo.txt
# 03-05-cairo.txt
# 03-06-cairo.txt
# 03-12-cairo.txt
# 03-14-cairo.txt
# 03-19-cairo.txt
# 03-24-cairo.txt
# 04-02-cairo.txt
# 04-06-cairo.txt
# 04-07-cairo.txt
# 04-10-cairo.txt
# 04-12-cairo.txt
# 04-13-cairo.txt
# 04-14-cairo.txt
# 04-15-cairo.txt
# 04-17-cairo.txt
# 04-20-cairo.txt
# 04-21-cairo.txt
# 04-22-cairo.txt
# 04-23-cairo.txt
# 04-24-cairo.txt
# 05-01-cairo.txt
# 05-02-cairo.txt
# 05-12-cairo.txt
# 05-17-cairo.txt
# 05-25-cairo.txt
# 05-27-cairo.txt
# 05-29-cairo.txt
# 05-30-cairo.txt
# 06-28-cairo.txt
# 07-04-cairo.txt
# 07-08-cairo.txt
# ...

# %%
os.getcwd()
# Out:
# 'C:\\Users\\ntyl1\\Documents\\GitHub\\learning-portfolio-ntyl03\\files, folders and os\\os-collaboration-exercise-data'
